# %% [markdown]
# # Multi-spectral Geospatial Translation (v2.0) - Colab Training
#
# This notebook trains the Dual-Stream, Frequency-Decoupled State-Space Mamba Network with Online Semantic and Direction-Aligned Structural Guardrails.

# %%
# !nvidia-smi

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Clone repo or copy from Google Drive (Adjust path to where your project is stored)
# !cp -r /content/drive/MyDrive/IR-Image-Colouring /content/IR-Image-Colouring
# %cd /content/IR-Image-Colouring

# %%
# Install dependencies
# !pip install -r requirements.txt

# %%
# Run the PyTorch Lightning training pipeline
# !python -m ircolor.training.train stage=joint train.epochs=100 train.batch_size=8

# %%
# Copy results back to Google Drive
# !cp -r /content/IR-Image-Colouring/lightning_logs /content/drive/MyDrive/IR-Image-Colouring/
